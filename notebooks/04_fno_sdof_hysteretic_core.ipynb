# %% [markdown]
# # 04. Hysteretic SDOF FNO & Physics Loss Ablations
# **Nonlinear Inelastic Response & Energy Balance**
#
# Investigates FNO performance under bilinear elastoplasticity and analyzes the effect of the thermodynamic energy consistency loss.

# %%
import pandas as pd
# Load unified baseline comparison
df_bench = pd.read_csv("results/tables/unified_baseline_benchmark.csv")
df_bench

# %%
# Inspect Post-Yield Error vs Elastic Error
print("Key Finding:")
print("FNO achieves strong linear-elastic accuracy (~10% error), but global Fourier bases")
print("experience spectral amnesia during post-yield stiffness degradation (~57% error).")
